# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_source = 'C:/Users/BiSBII/Documents/MM_ML/data/DIABLO_INPUT'
folder = os.path.join(data_source, 'splits')

# %% [markdown]
# # RNA + METS

# %% [markdown]
# # Component 1

# %% [markdown]
# ## DNA

# %%
all_dfs_cp1_dna = []
for i in range(5):
    df = pd.read_csv(os.path.join(folder, 'SPLITS_DNA_LOADINGS_' + str(i) + '.csv'), index_col=0)
    all_dfs_cp1_dna.append(df['comp1'])

# %%
df_cp1_dna = pd.concat(all_dfs_cp1_dna, axis=1)
df_cp1_dna.columns = ['comp1_1', 'comp1_2', 'comp1_3', 'comp1_4', 'comp1_5']
df_cp1_dna = df_cp1_dna.fillna(0)
df_cp1_dna = abs(df_cp1_dna)

# %%
df_cp1_dna['mean'] = df_cp1_dna.mean(axis=1)
df_cp1_dna = df_cp1_dna.sort_values(by=['mean'], ascending=False)
df_cp1_dna
# Out:
#                 comp1_1   comp1_2   comp1_3   comp1_4   comp1_5      mean
# Vitvi05g00565  0.142294  0.145996  0.138082  0.127848  0.132135  0.137271
# Vitvi10g00609  0.221822  0.072639  0.081237  0.132293  0.148108  0.131220
# Vitvi18g00924  0.182015  0.094513  0.092839  0.141782  0.134522  0.129134
# Vitvi14g01811  0.183180  0.106692  0.098436  0.114577  0.136370  0.127851
# Vitvi13g00606  0.204034  0.068807  0.107599  0.105529  0.125967  0.122387
# ...                 ...       ...       ...       ...       ...       ...
# Vitvi18g02625  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Vitvi04g01836  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Vitvi18g02240  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Vitvi04g02179  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Vitvi19g01751  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
# [765 rows x 6 columns]

# %%
cols = ['tab:blue'] * 15
cols[3] = 'tab:orange'
cols
# Out:
# ['tab:blue',
#  'tab:blue',
#  'tab:blue',
#  'tab:orange',
#  'tab:blue',
#  'tab:blue',
#  'tab:blue',
#  'tab:blue',
#  'tab:blue',
#  'tab:blue',
#  'tab:blue',
#  'tab:blue',
#  'tab:blue',
#  'tab:blue',
#  'tab:blue']

# %%
plt.barh(df_cp1_dna.iloc[:15, -1].index, df_cp1_dna.iloc[:15, -1], color=cols)
# Out:
# <BarContainer object of 15 artists>

# %% [markdown]
# ## METS

# %%
all_dfs_cp1_mets = []
for i in range(5):
    df = pd.read_csv(os.path.join(folder, 'SPLITS_METS_LOADINGS_' + str(i) + '.csv'), index_col=0)
    all_dfs_cp1_mets.append(df['comp1'])

# %%
df_cp1_mets = pd.concat(all_dfs_cp1_mets, axis=1)
df_cp1_mets.columns = ['comp1_1', 'comp1_2', 'comp1_3', 'comp1_4', 'comp1_5']
df_cp1_mets = df_cp1_mets.fillna(0)
df_cp1_mets = abs(df_cp1_mets)

# %%
df_cp1_mets['mean'] = df_cp1_mets.mean(axis=1)
df_cp1_mets = df_cp1_mets.sort_values(by=['mean'], ascending=False)
df_cp1_mets
# Out:
#                       comp1_1   comp1_2   comp1_3   comp1_4   comp1_5  \
# malic.acid           0.191411  0.378441  0.386806  0.195144  0.197281
# sucrose              0.189651  0.354842  0.397312  0.196722  0.197185
# glucose              0.191747  0.325844  0.372821  0.192818  0.193051
# threonic.acid        0.184243  0.273858  0.239243  0.180332  0.178294
# lactitol             0.174695  0.269662  0.249953  0.169391  0.172636
# ...                       ...       ...       ...       ...       ...
# glyceric.acid        0.000000  0.000000  0.000000  0.000000  0.000000
# glucose.1.phosphate  0.000000  0.000000  0.000000  0.000000  0.000000
# X1.monopalmitin      0.000000  0.000000  0.000000  0.000000  0.000000
# X1.monostearin       0.000000  0.000000  0.000000  0.000000  0.000000
# dehydroabietic.acid  0.000000  0.000000  0.000000  0.000000  0.000000
#
#                          mean
# malic.acid           0.269817
# sucrose              0.267142
# glucose              0.255256
# ...

# %%
colors = ['tab:blue', 'tab:orange', 'tab:orange', 'tab:blue', 'tab:orange', 'tab:blue', 'tab:orange', 'tab:orange', 'tab:orange', 'tab:blue', 'tab:orange', 'tab:orange', 'tab:orange', 'tab:blue', 'tab:orange']

# %%
plt.barh(df_cp1_mets.iloc[:15, -1].index, df_cp1_mets.iloc[:15, -1], color=colors)
# Out:
# <BarContainer object of 15 artists>

# %% [markdown]
# # COMP2

# %% [markdown]
# ## DNA

# %%
all_dfs = []
for i in range(5):
    df = pd.read_csv(os.path.join(folder, 'SPLITS_DNA_LOADINGS_' + str(i) + '.csv'), index_col=0)
    all_dfs.append(df['comp2'])

# %%
df_cp2 = pd.concat(all_dfs, axis=1)
df_cp2.columns = ['comp2_1', 'comp2_2', 'comp2_3', 'comp2_4', 'comp2_5']
df_cp2 = df_cp2.fillna(0)
df_cp2 = abs(df_cp2)

# %%
df_cp2['mean'] = df_cp2.mean(axis=1)
df_cp2 = df_cp2.sort_values(by=['mean'], ascending=False)
df_cp2
# Out:
#                 comp2_1  comp2_2   comp2_3   comp2_4   comp2_5      mean
# Vitvi01g00800  0.404653      0.0  0.131574  0.458472  0.539032  0.306746
# Vitvi08g01059  0.158284      0.0  0.054737  0.265504  0.370413  0.169788
# Vitvi03g04146  0.210200      0.0  0.018404  0.216414  0.256422  0.140288
# Vitvi18g00216  0.000000      0.0  0.000000  0.163107  0.449139  0.122449
# Vitvi15g00046  0.425418      0.0  0.000000  0.000000  0.152055  0.115495
# ...                 ...      ...       ...       ...       ...       ...
# Vitvi12g02334  0.000000      0.0  0.000000  0.000000  0.000000  0.000000
# Vitvi12g02659  0.000000      0.0  0.000000  0.000000  0.000000  0.000000
# Vitvi13g00004  0.000000      0.0  0.000000  0.000000  0.000000  0.000000
# Vitvi13g00017  0.000000      0.0  0.000000  0.000000  0.000000  0.000000
# Vitvi19g01751  0.000000      0.0  0.000000  0.000000  0.000000  0.000000
#
# [765 rows x 6 columns]

# %%
cols = ['tab:blue'] * 15
cols[5] = 'tab:orange'
cols
# Out:
# ['tab:blue',
#  'tab:blue',
#  'tab:blue',
#  'tab:blue',
#  'tab:blue',
#  'tab:orange',
#  'tab:blue',
#  'tab:blue',
#  'tab:blue',
#  'tab:blue',
#  'tab:blue',
#  'tab:blue',
#  'tab:blue',
#  'tab:blue',
#  'tab:blue']

# %%
plt.barh(df_cp2.iloc[:15, -1].index, df_cp2.iloc[:15, -1], color=cols)
# Out:
# <BarContainer object of 15 artists>

# %% [markdown]
# ## METS

# %%
all_dfs = []
for i in range(5):
    df = pd.read_csv(os.path.join(folder, 'SPLITS_METS_LOADINGS_' + str(i) + '.csv'), index_col=0)
    all_dfs.append(df['comp2'])

# %%
df_cp2 = pd.concat(all_dfs, axis=1)
df_cp2.columns = ['comp2_1', 'comp2_2', 'comp2_3', 'comp2_4', 'comp2_5']
df_cp2 = df_cp2.fillna(0)
df_cp2 = abs(df_cp2)

# %%
df_cp2['mean'] = df_cp2.mean(axis=1)
df_cp2 = df_cp2.sort_values(by=['mean'], ascending=False)
df_cp2
# Out:
#                       comp2_1   comp2_2   comp2_3   comp2_4   comp2_5  \
# aspartic.acid        0.179909  0.000000  0.027806  0.433360  0.495606
# L.saccharopine       0.106218  0.000000  0.087006  0.353246  0.487310
# glucose.1.phosphate  0.115012  0.000000  0.090176  0.413122  0.332802
# shikimic.acid        0.128413  0.465623  0.173808  0.000000  0.000000
# myo.inositol         0.044008  0.199780  0.158495  0.305822  0.000000
# ...                       ...       ...       ...       ...       ...
# glyceric.acid        0.011045  0.000000  0.005682  0.000000  0.000000
# lysine               0.014227  0.000000  0.000000  0.000000  0.000000
# citric.acid          0.012964  0.000000  0.000000  0.000000  0.000000
# stearic.acid         0.004779  0.000000  0.002111  0.000000  0.000000
# X13.docosenamide     0.000000  0.000000  0.002882  0.000000  0.000000
#
#                          mean
# aspartic.acid        0.227336
# L.saccharopine       0.206756
# glucose.1.phosphate  0.190222
# ...

# %%
cols = ['tab:blue'] * 3 + ['tab:orange'] * 6 + ['tab:blue', 'tab:orange', 'tab:blue', 'tab:orange', 'tab:orange', 'tab:blue']

# %%
plt.barh(df_cp2.iloc[:15, -1].index, df_cp2.iloc[:15, -1], color=cols)
# Out:
# <BarContainer object of 15 artists>

# %%
mets4 = pd.read_csv(os.path.join(data_source, 'XTRAIN_METABOLOMICS_NOREPS_VT_SPLIT_4.csv'), index_col=0)

# %%
mets3 = pd.read_csv(os.path.join(data_source, 'XTRAIN_METABOLOMICS_NOREPS_VT_SPLIT_3.csv'), index_col=0)

# %%
y_train4 = pd.read_csv(os.path.join(data_source, 'yTRAIN_ALL_GENES_NOREPS_SPLIT_4.csv'), index_col=0)
y_train3 = pd.read_csv(os.path.join(data_source, 'yTRAIN_ALL_GENES_NOREPS_SPLIT_3.csv'), index_col=0)

# %%
mets3['glucose-1-phosphate'].plot(kind='bar', figsize=(20,10))
# Out:
# <Axes: >

# %%
mets3['glucose-1-phosphate'].groupby(y_train3['state']).mean()
# Out:
# state
# green     0.112019
# mature   -0.076813
# Name: glucose-1-phosphate, dtype: float64

# %% [markdown]
# # RNA + FLUXES

# %% [markdown]
# ## COMP1

# %% [markdown]
# ### RNA

# %%
all_dfs_cp1_dna = []
for i in range(5):
    df = pd.read_csv(os.path.join(folder, 'SPLITS_DNA_FLUX_LOADINGS_' + str(i) + '.csv'), index_col=0)
    all_dfs_cp1_dna.append(df['comp1'])

# %%
df_cp1_dna = pd.concat(all_dfs_cp1_dna, axis=1)
df_cp1_dna.columns = ['comp1_1', 'comp1_2', 'comp1_3', 'comp1_4', 'comp1_5']
df_cp1_dna = df_cp1_dna.fillna(0)
df_cp1_dna = abs(df_cp1_dna)

# %%
df_cp1_dna['mean'] = df_cp1_dna.mean(axis=1)
df_cp1_dna = df_cp1_dna.sort_values(by=['mean'], ascending=False)
df_cp1_dna
# Out:
#                 comp1_1   comp1_2   comp1_3   comp1_4   comp1_5      mean
# Vitvi04g00501  0.701364  0.590401  0.689587  0.059819  0.059829  0.420200
# Vitvi01g00052  0.259256  0.315667  0.184619  0.119845  0.134980  0.202873
# Vitvi18g00683  0.011289  0.410593  0.354904  0.000000  0.007076  0.156772
# Vitvi17g00557  0.229494  0.109574  0.165901  0.085517  0.131887  0.144474
# Vitvi06g00513  0.116642  0.158482  0.275638  0.055922  0.091738  0.139684
# ...                 ...       ...       ...       ...       ...       ...
# Vitvi12g00202  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Vitvi12g00200  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Vitvi12g00188  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Vitvi12g00115  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Vitvi14g04680  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
# [765 rows x 6 columns]

# %%
cols = ['tab:blue'] * 15
#cols[3] = 'tab:orange'
#cols

# %%
plt.barh(df_cp1_dna.iloc[:15, -1].index, df_cp1_dna.iloc[:15, -1], color=cols)
# Out:
# <BarContainer object of 15 artists>

# %% [markdown]
# ### FLUXES

# %%
all_dfs_cp1_flux = []
for i in range(5):
    df = pd.read_csv(os.path.join(folder, 'SPLITS_FLUX_LOADINGS_' + str(i) + '.csv'), index_col=0)
    all_dfs_cp1_flux.append(df['comp1'])

# %%
df_cp1_flux = pd.concat(all_dfs_cp1_flux, axis=1)
df_cp1_flux.columns = ['comp1_1', 'comp1_2', 'comp1_3', 'comp1_4', 'comp1_5']
df_cp1_flux = df_cp1_flux.fillna(0)
df_cp1_flux = abs(df_cp1_flux)

# %%
df_cp1_flux['mean'] = df_cp1_flux.mean(axis=1)
df_cp1_flux = df_cp1_flux.sort_values(by=['mean'], ascending=False)
df_cp1_flux
# Out:
#                                 comp1_1   comp1_2   comp1_3   comp1_4  \
# CYTIDEAM2.RXN__mito            0.337063  0.426418  0.320024  0.197395
# RXN.14325__cyto                0.337062  0.426416  0.320023  0.197394
# CTPSYN.RXN__cyto               0.325570  0.434642  0.315963  0.183643
# CDPKIN.RXN__mito               0.257533  0.224881  0.228608  0.201324
# CDPKIN.RXN__cyto               0.257533  0.224881  0.228608  0.201324
# ...                                 ...       ...       ...       ...
# RXN.10862__chlo                0.000000  0.000000  0.000000  0.000000
# RXN.14198__er                  0.000000  0.000000  0.000000  0.000000
# RXN.14198__cyto                0.000000  0.000000  0.000000  0.000000
# X6PGLUCONOLACT.RXN__cyto       0.000000  0.000000  0.000000  0.000000
# TR2000023__mito__cyto_reverse  0.000000  0.000000  0.000000  0.000000
#
#                                 comp1_5      mean
# CYTIDEAM2.RXN__mito            0.228387  0.301858
# ...

# %%
cols = ['tab:blue'] * 15
#cols[3] = 'tab:orange'
cols
# Out:
# ['tab:blue',
#  'tab:blue',
#  'tab:blue',
#  'tab:blue',
#  'tab:blue',
#  'tab:blue',
#  'tab:blue',
#  'tab:blue',
#  'tab:blue',
#  'tab:blue',
#  'tab:blue',
#  'tab:blue',
#  'tab:blue',
#  'tab:blue',
#  'tab:blue']

# %%
plt.barh(df_cp1_flux.iloc[:15, -1].index, df_cp1_flux.iloc[:15, -1], color=cols)
# Out:
# <BarContainer object of 15 artists>

# %% [markdown]
# # COMP2

# %% [markdown]
# ## RNA

# %%
all_dfs = []
for i in range(5):
    df = pd.read_csv(os.path.join(folder, 'SPLITS_DNA_FLUX_LOADINGS_' + str(i) + '.csv'), index_col=0)
    all_dfs.append(df['comp2'])

# %%
df_cp2 = pd.concat(all_dfs, axis=1)
df_cp2.columns = ['comp2_1', 'comp2_2', 'comp2_3', 'comp2_4', 'comp2_5']
df_cp2 = df_cp2.fillna(0)
df_cp2 = abs(df_cp2)

# %%
df_cp2['mean'] = df_cp2.mean(axis=1)
df_cp2 = df_cp2.sort_values(by=['mean'], ascending=False)
df_cp2
# Out:
#                 comp2_1   comp2_2   comp2_3   comp2_4   comp2_5      mean
# Vitvi12g00200  0.000000  0.000802  0.000000  0.327132  0.456173  0.156821
# Vitvi19g01952  0.000000  0.000000  0.000000  0.267127  0.391781  0.131782
# Vitvi17g00621  0.000000  0.000000  0.000000  0.179754  0.458708  0.127692
# Vitvi06g01349  0.000000  0.000000  0.008904  0.318207  0.236823  0.112787
# Vitvi04g00325  0.113023  0.154891  0.117023  0.083348  0.000000  0.093657
# ...                 ...       ...       ...       ...       ...       ...
# Vitvi13g00085  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Vitvi13g00004  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Vitvi12g04375  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Vitvi12g02334  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# Vitvi19g01751  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
# [765 rows x 6 columns]

# %%
cols = ['tab:blue'] * 15
cols[2] = 'tab:orange'
cols[11] = 'tab:orange'
cols
# Out:
# ['tab:blue',
#  'tab:blue',
#  'tab:orange',
#  'tab:blue',
#  'tab:blue',
#  'tab:blue',
#  'tab:blue',
#  'tab:blue',
#  'tab:blue',
#  'tab:blue',
#  'tab:blue',
#  'tab:orange',
#  'tab:blue',
#  'tab:blue',
#  'tab:blue']

# %%
plt.barh(df_cp2.iloc[:15, -1].index, df_cp2.iloc[:15, -1], color=cols)
# Out:
# <BarContainer object of 15 artists>

# %% [markdown]
# ## FLUX

# %%
all_dfs = []
for i in range(5):
    df = pd.read_csv(os.path.join(folder, 'SPLITS_FLUX_LOADINGS_' + str(i) + '.csv'), index_col=0)
    all_dfs.append(df['comp2'])

# %%
df_cp2_flux = pd.concat(all_dfs, axis=1)
df_cp2_flux.columns = ['comp2_1', 'comp2_2', 'comp2_3', 'comp2_4', 'comp2_5']
df_cp2_flux = df_cp2_flux.fillna(0)
df_cp2_flux = abs(df_cp2_flux)

# %%
df_cp2_flux['mean'] = df_cp2_flux.mean(axis=1)
df_cp2_flux = df_cp2_flux.sort_values(by=['mean'], ascending=False)
df_cp2_flux
# Out:
#                                    comp2_1   comp2_2   comp2_3   comp2_4  \
# TR2000023__mito__cyto_reverse     0.000000  0.000000  0.000000  0.593757
# TR2000023__mito__cyto             0.000000  0.000000  0.000000  0.593757
# RXN.12959__er                     0.379840  0.347304  0.329354  0.000000
# L.ASCORBATE.PEROXIDASE.RXN__cyto  0.381128  0.247842  0.320169  0.000000
# X1.1.1.248.RXN__cyto              0.307650  0.316470  0.307798  0.000000
# ...                                    ...       ...       ...       ...
# RXN.14208__cyto                   0.000000  0.000000  0.000000  0.000000
# ADENOSINE.KINASE.RXN__cyto        0.000000  0.000000  0.000000  0.000000
# TI1000430__cyto__extr             0.000000  0.000000  0.000000  0.000000
# BETA.UREIDOPROPIONASE.RXN__cyto   0.000000  0.000000  0.000000  0.000000
# RXN.12196__cyto                   0.000000  0.000000  0.000000  0.000000
#
#                                   comp2_5      mean
# ...

# %%
cols = ['tab:blue'] * 15
cols[9] = 'tab:orange'
cols[10] = 'tab:orange'
cols[11] = 'tab:orange'
cols[12] = 'tab:orange'
cols[13] = 'tab:orange'
cols[14] = 'tab:orange'
cols
# Out:
# ['tab:blue',
#  'tab:blue',
#  'tab:blue',
#  'tab:blue',
#  'tab:blue',
#  'tab:blue',
#  'tab:blue',
#  'tab:blue',
#  'tab:blue',
#  'tab:orange',
#  'tab:orange',
#  'tab:orange',
#  'tab:orange',
#  'tab:orange',
#  'tab:orange']

# %%
plt.barh(df_cp2_flux.iloc[:15, -1].index, df_cp2_flux.iloc[:15, -1], color=cols)
# Out:
# <BarContainer object of 15 artists>
